# %% [markdown]
# ### Experiment with GPT4.1-mini

# %%
import pandas as pd
import libs.prompts as prompts
from libs.exp_utils import classify_dataset, evaluate_experiment
import json

# %%
# Define model name
MODEL_NAME = "gpt-4.1-mini"

# %% [markdown]
# ### Dataset load

# %%
# Load the dataset and convert to appropriate data types
csv_path = "../../Datasets/dataset.csv"  # Path to the CSV file
df = pd.read_csv(csv_path)

# Ensure that data types are correct
df['has_error'] = df['has_error'].astype(bool)

subset = df.reset_index(drop=True)

# %% [markdown]
# ### Experiment With Combined Dataset

# %% [markdown]
# #### Zero-shot Prompting

# %%
results_df = classify_dataset(subset, prompts.create_zeroshot_prompt, MODEL_NAME)
precision, recall, f1, conf_matrix = evaluate_experiment(results_df)

# Display the metrics
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# 400it [05:44,  1.16it/s]
# Precision: 61.39
# Recall: 79.50
# F1-Score: 69.28
# Confusion Matrix:
# [[100 100]
#  [ 41 159]]

# %% [markdown]
# #### Zero-shot CoT Prompting

# %%
results_df = classify_dataset(subset, prompts.create_zeroshot_cot_prompt, MODEL_NAME)
precision, recall, f1, conf_matrix = evaluate_experiment(results_df)

# Display the metrics
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# 400it [1:00:54,  9.14s/it]
# Precision: 61.07
# Recall: 85.50
# F1-Score: 71.25
# Confusion Matrix:
# [[ 91 109]
#  [ 29 171]]

# %% [markdown]
# #### Zero-shot ToT Prompting

# %%
results_df = classify_dataset(subset, prompts.create_zeroshot_tot_prompt, MODEL_NAME)
precision, recall, f1, conf_matrix = evaluate_experiment(results_df)

# Display the metrics
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# 188it [46:09, 167.06s/it]
# {
#   "has_error": true,
#   "reasoning_paths": [
#     {
#       "path": "Use of 'now' keyword and timestamp casting",
#       "analysis": "The contract uses 'now' in the line `uint32 public investmentsDeadlineTimeStamp = uint32(now);`. In Solidity 0.6.2, 'now' is deprecated and is an alias for 'block.timestamp'. While this is not a compilation error, it is discouraged and may cause confusion. Additionally, casting 'now' (a uint256) to uint32 can cause overflow issues if the timestamp exceeds the uint32 max value (which will happen in the year 2106). This is not an immediate error but a potential future bug."
#     },
#     {
#       "path": "Incorrect use of bytes16 and bytes32 for string literals",
#       "analysis": "The contract declares `bytes16 private string1 = \"test1\";` and `bytes32 private string2 = \"test1236\";`. Assigning string literals directly to fixed-size byte arrays is allowed if the string fits within the byte array size. 'test1' is 5 bytes, so it fits into bytes16, and 'test1236' is 8 bytes, so it fits into bytes32. This is valid and will pad the remaining bytes with zeros. No error here."
#     },
#     {
#       "path": "Mapping and struct usage",
#       "analysis": "The contract defines a struct DeviceData and uses mappings and arrays to store instances. The function testStorage creates a DeviceData in memory and assigns it to a mapping and pushes it to an array. This is valid usage and compiles correctly."
#     },
#     {
#       "path": "Use of transfer on msg.sender",
#       "analysis": "In the function `_sendWinnings()`, the contract calls `msg.sender.transfer(address(this).balance);`. In Solidity 0.6.x, 'transfer' is a member of 'address payable', and 'msg.sender' is of type 'address' by default. However, in 0.6.x, 'msg.sender' is of type 'address payable', so this is valid. No error here. However, using transfer is discouraged due to gas stipend issues, but this is not a compilation error."
#     }
# Erro ao decodificar JSON para NoImplicitVisibility.sol: Expecting ',' delimiter: line 19 column 6 (char 1931)
# 400it [1:41:04, 15.16s/it]
# Precision: 62.96
# Recall: 85.00
# F1-Score: 72.34
# Confusion Matrix:
# [[ 99 100]
#  [ 30 170]]
